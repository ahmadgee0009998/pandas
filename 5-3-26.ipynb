# %%
import numpy as np
import pandas as pd
s = pd.Series([1,2,3,4,5],index=['a','b','c','d','e'])
print(s)
print(type(s))
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64
# <class 'pandas.Series'>

# %%
df = pd.DataFrame({"Name":["Ahmad","Ali","Saad","Abdullah","Usman"], "Age":[21,15,22,22,25],"Marks":[87,78,85,78,89]})
df
# Out:
#        Name  Age  Marks
# 0     Ahmad   21     87
# 1       Ali   15     78
# 2      Saad   22     85
# 3  Abdullah   22     78
# 4     Usman   25     89

# %%
df.head(2)
df.tail(3)
df.shape
df.columns
# Out:
# Index(['Name', 'Age', 'Marks'], dtype='str')

# %%
df[["Age","Marks"]]
# Out:
#    Age  Marks
# 0   21     87
# 1   15     78
# 2   22     85
# 3   22     78
# 4   25     89

# %%
df.loc[1]
df.iloc[2]
# Out:
# Name     Saad
# Age        22
# Marks      85
# Name: 2, dtype: object

# %%
df[df["Age"]<22]
# Out:
#     Name  Age  Marks
# 0  Ahmad   21     87
# 1    Ali   15     78

# %%
df["Department"]=['It','Cs','It','Eng','Math']
df
# Out:
#        Name  Age  Marks Department
# 0     Ahmad   21     87         It
# 1       Ali   15     78         Cs
# 2      Saad   22     85         It
# 3  Abdullah   22     78        Eng
# 4     Usman   25     89       Math

# %%
df["Age"]=df["Age"]+1
df
# Out:
#        Name  Age  Marks Department
# 0     Ahmad   22     87         It
# 1       Ali   16     78         Cs
# 2      Saad   23     85         It
# 3  Abdullah   23     78        Eng
# 4     Usman   26     89       Math

# %%
df.sort_values("Age",ascending=True)
# Out:
#        Name  Age  Marks Department
# 1       Ali   16     78         Cs
# 0     Ahmad   22     87         It
# 2      Saad   23     85         It
# 3  Abdullah   23     78        Eng
# 4     Usman   26     89       Math

# %%
df["Marks"].sum()
df["Marks"].mean()
df["Marks"].max()
df["Marks"].min()
# Out:
# np.int64(78)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        5 non-null      str
#  1   Age         5 non-null      int64
#  2   Marks       5 non-null      int64
#  3   Department  5 non-null      str
# dtypes: int64(2), str(2)
# memory usage: 292.0 bytes

# %%
df.iloc[2,2]
# Out:
# np.int64(85)

# %%
data = {
    "Name": ["Ali","Sara","Ahmed","Ayesha","Bilal"],
    "Age": [21,22,23,20,24],
    "City": ["Lahore","Karachi","Islamabad","Lahore","Karachi"],
    "Salary": [40000,50000,45000,38000,52000]
}

df = pd.DataFrame(data)
print(df)
# Out:
#      Name  Age       City  Salary
# 0     Ali   21     Lahore   40000
# 1    Sara   22    Karachi   50000
# 2   Ahmed   23  Islamabad   45000
# 3  Ayesha   20     Lahore   38000
# 4   Bilal   24    Karachi   52000

# %%
df[["Name","Salary"]]
df.iloc[1,3]
df.iloc[0:2,0:2]
df.loc[:,"City"]
df.iloc[2,3]
df.loc[3,"Age"]
# Out:
# np.int64(20)

# %%
df[(df["Age"]<23) & (df["Salary"]>40000)]
# Out:
#    Name  Age     City  Salary
# 1  Sara   22  Karachi   50000

# %%
df2 = pd.DataFrame(np.random.rand(50,50))
df3 = np.random.rand(50,50) < 0.2
df2[df3] = np.nan
print(df2)
# Out:
#           0         1         2         3         4         5         6   \
# 0   0.528069  0.702883  0.682178  0.237115  0.953020  0.835303  0.130616
# 1   0.969145  0.318191  0.832526       NaN       NaN  0.057335  0.426382
# 2   0.243859  0.454571  0.752819  0.413220  0.150091  0.999108       NaN
# 3        NaN  0.518804  0.821104  0.143476  0.885707  0.982492       NaN
# 4   0.603829  0.037998  0.185788       NaN  0.452775  0.736327  0.186252
# 5   0.128957  0.615485  0.289498  0.324988  0.981643  0.515535  0.486187
# 6        NaN       NaN  0.928206  0.097299  0.106138  0.564338  0.259910
# 7   0.711159  0.365445  0.503940  0.886966  0.529377  0.824429  0.210091
# 8   0.573904  0.541716  0.670184  0.482506  0.684076  0.383224       NaN
# 9   0.349702  0.794439  0.876504       NaN  0.468183  0.547721  0.543162
# 10  0.980704  0.172945  0.814023  0.677274       NaN  0.915711  0.536979
# 11       NaN  0.778000  0.298294  0.714916  0.745919       NaN  0.145118
# ...

# %%
df4 = pd.DataFrame(np.random.rand(50,50))
df5 = np.random.rand(50,50) < 0.2
df4[df5]=np.nan
df4
# Out:
#           0         1         2         3         4         5         6   \
# 0   0.851428       NaN  0.406073  0.660073  0.794169  0.488605  0.690831
# 1   0.719154       NaN  0.966275  0.228677  0.584229  0.957153  0.690577
# 2   0.356139  0.483538  0.592071  0.319383       NaN  0.132353  0.456544
# 3   0.499787  0.140323  0.560505       NaN  0.604912  0.475288  0.401473
# 4   0.040011       NaN  0.391543  0.008935  0.185620  0.924388  0.336755
# 5   0.307783  0.706773       NaN  0.282244  0.544666  0.349754  0.414697
# 6   0.844631       NaN       NaN  0.336502       NaN  0.507019  0.773484
# 7   0.033353  0.555769  0.180214  0.509145  0.421614  0.346218  0.080158
# 8   0.511613  0.162527  0.253041  0.984737  0.526304  0.355458  0.931317
# 9   0.835034  0.488157  0.238482  0.592591  0.334288  0.072376       NaN
# 10  0.909032  0.668701  0.552462  0.494705       NaN  0.759956  0.017976
# 11  0.906649  0.328744  0.100892  0.325513  0.426405  0.029579  0.129792
# ...
